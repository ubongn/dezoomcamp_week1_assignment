# %%
import pandas as pd

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
# %pip install sqlalchemy psycopg2-binary --user
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\ubong\anaconda3\lib\site-packages (1.4.39)
# Requirement already satisfied: psycopg2-binary in c:\users\ubong\anaconda3\lib\site-packages (2.9.5)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ubong\anaconda3\lib\site-packages (from sqlalchemy) (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
engine = create_engine('postgresql://root:root@localhost:5431/ny_taxi')

# %%
engine.connect()

# %%
df_green_taxi = pd.read_csv('green_tripdata_2019-01.csv', nrows=100)

# %%
df_green_taxi
# Out:
#     VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0          2  2018-12-21 15:17:29   2018-12-21 15:18:57                  N
# 1          2  2019-01-01 00:10:16   2019-01-01 00:16:32                  N
# 2          2  2019-01-01 00:27:11   2019-01-01 00:31:38                  N
# 3          2  2019-01-01 00:46:20   2019-01-01 01:04:54                  N
# 4          2  2019-01-01 00:19:06   2019-01-01 00:39:43                  N
# ..       ...                  ...                   ...                ...
# 95         2  2019-01-01 00:15:42   2019-01-01 00:41:04                  N
# 96         2  2019-01-01 00:21:28   2019-01-01 00:48:15                  N
# 97         2  2019-01-01 00:17:10   2019-01-01 00:23:34                  N
# 98         2  2019-01-01 00:25:01   2019-01-01 00:43:55                  N
# 99         2  2019-01-01 00:36:56   2019-01-01 00:43:50                  N
#
#     RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0            1           264           264                5           0.00
# 1            1            97            49                2           0.86
# 2            1            49           189                2           0.66
# 3            1           189            17                2           2.68
# 4            1            82           258                1           4.53
# ..         ...           ...           ...              ...            ...
# 95           1            97           179                1           7.83
# 96           1             7           230                1           4.49
# 97           1            42            42                1           1.08
# 98           1            42           232                2           8.74
# 99           1           223             7                5           1.32
#
#     fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0           3.0    0.5      0.5        0.00           0.0        NaN
# 1           6.0    0.5      0.5        0.00           0.0        NaN
# 2           4.5    0.5      0.5        0.00           0.0        NaN
# 3          13.5    0.5      0.5        2.96           0.0        NaN
# 4          18.0    0.5      0.5        0.00           0.0        NaN
# ..          ...    ...      ...         ...           ...        ...
# 95         26.0    0.5      0.5        5.46           0.0        NaN
# 96         20.0    0.5      0.5        4.00           0.0        NaN
# 97          6.5    0.5      0.5        0.00           0.0        NaN
# 98         25.0    0.5      0.5        0.00           0.0        NaN
# 99          7.0    0.5      0.5        2.00           0.0        NaN
#
#     improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                     0.3          4.30             2          1
# 1                     0.3          7.30             2          1
# 2                     0.3          5.80             1          1
# 3                     0.3         19.71             1          1
# 4                     0.3         19.30             2          1
# ..                    ...           ...           ...        ...
# 95                    0.3         32.76             1          1
# 96                    0.3         25.30             1          1
# 97                    0.3          7.80             2          1
# 98                    0.3         26.30             2          1
# 99                    0.3         10.30             1          1
#
#     congestion_surcharge
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ..                   ...
# 95                   NaN
# 96                   NaN
# 97                   NaN
# 98                   NaN
# 99                   NaN
#
# [100 rows x 20 columns]

# %%
df_location = pd.read_csv('taxi+_zone_lookup.csv')

# %%
df_location.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
df = pd.read_csv('green_tripdata_2019-01.csv')

# %%
print(pd.io.sql.get_schema(df, name='green_tripdata_2019', con=engine))
# Out:
# CREATE TABLE green_tripdata_2019 (
# 	"VendorID" BIGINT,
# 	lpep_pickup_datetime TEXT,
# 	lpep_dropoff_datetime TEXT,
# 	store_and_fwd_flag TEXT,
# 	"RatecodeID" BIGINT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	ehail_fee FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	payment_type BIGINT,
# 	trip_type BIGINT,
# 	congestion_surcharge FLOAT(53)
# )

# %%
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %%
print(pd.io.sql.get_schema(df, name='green_taxi_data', con=engine))
# Out:
# CREATE TABLE green_taxi_data (
# 	"VendorID" BIGINT,
# 	lpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	lpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	store_and_fwd_flag TEXT,
# 	"RatecodeID" BIGINT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	ehail_fee FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	payment_type BIGINT,
# 	trip_type BIGINT,
# 	congestion_surcharge FLOAT(53)
# )

# %%
df_iter = pd.read_csv('green_tripdata_2019-01.csv', iterator=True, chunksize=100000)

# %%
df = next(df_iter)

# %%
len(df)
# Out:
# 100000

# %%
df.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2018-12-21 15:17:29   2018-12-21 15:18:57                  N
# 1         2  2019-01-01 00:10:16   2019-01-01 00:16:32                  N
# 2         2  2019-01-01 00:27:11   2019-01-01 00:31:38                  N
# 3         2  2019-01-01 00:46:20   2019-01-01 01:04:54                  N
# 4         2  2019-01-01 00:19:06   2019-01-01 00:39:43                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0           1           264           264                5           0.00
# 1           1            97            49                2           0.86
# 2           1            49           189                2           0.66
# 3           1           189            17                2           2.68
# 4           1            82           258                1           4.53
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0          3.0    0.5      0.5        0.00           0.0        NaN
# 1          6.0    0.5      0.5        0.00           0.0        NaN
# 2          4.5    0.5      0.5        0.00           0.0        NaN
# 3         13.5    0.5      0.5        2.96           0.0        NaN
# 4         18.0    0.5      0.5        0.00           0.0        NaN
#
#    improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                    0.3          4.30             2          1
# 1                    0.3          7.30             2          1
# 2                    0.3          5.80             1          1
# 3                    0.3         19.71             1          1
# 4                    0.3         19.30             2          1
#
#    congestion_surcharge
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %%
df.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2018-12-21 15:17:29   2018-12-21 15:18:57                  N
# 1         2  2019-01-01 00:10:16   2019-01-01 00:16:32                  N
# 2         2  2019-01-01 00:27:11   2019-01-01 00:31:38                  N
# 3         2  2019-01-01 00:46:20   2019-01-01 01:04:54                  N
# 4         2  2019-01-01 00:19:06   2019-01-01 00:39:43                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0           1           264           264                5           0.00
# 1           1            97            49                2           0.86
# 2           1            49           189                2           0.66
# 3           1           189            17                2           2.68
# 4           1            82           258                1           4.53
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0          3.0    0.5      0.5        0.00           0.0        NaN
# 1          6.0    0.5      0.5        0.00           0.0        NaN
# 2          4.5    0.5      0.5        0.00           0.0        NaN
# 3         13.5    0.5      0.5        2.96           0.0        NaN
# 4         18.0    0.5      0.5        0.00           0.0        NaN
#
#    improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                    0.3          4.30             2          1
# 1                    0.3          7.30             2          1
# 2                    0.3          5.80             1          1
# 3                    0.3         19.71             1          1
# 4                    0.3         19.30             2          1
#
#    congestion_surcharge
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
df.head(n=0).to_sql(name='green_taxi_data', con=engine, if_exists='replace')
# Out:
# 0

# %%
# %time df.to_sql(name='green_taxi_data', con=engine, if_exists='append')
# Out:
# Wall time: 15.2 s
# 1000

# %%
from time import time

# %%
while True:
    t_start = time()

    df = next(df_iter)

    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

    df.to_sql(name='green_taxi_data', con=engine, if_exists='append')

    t_end = time()

    print("inserted another chunk... took %.3f second" % (t_end - t_start))
# Out:
# inserted another chunk... took 16.260 second
# inserted another chunk... took 15.257 second
# inserted another chunk... took 15.116 second
# inserted another chunk... took 15.216 second
# inserted another chunk... took 16.555 second
# inserted another chunk... took 4.927 second
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24460\4260976686.py in <module>
#       2     t_start = time()
#       3
# ----> 4     df = next(df_iter)
#       5
#       6     df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __next__(self)
#    1184     def __next__(self):
#    1185         try:
# -> 1186             return self.get_chunk()
#    1187         except StopIteration:
#    1188             self.close()
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in get_chunk(self, size)
#    1281                 raise StopIteration
#    1282             size = min(size, self.nrows - self._currow)
# -> 1283         return self.read(nrows=size)
#    1284
#    1285     def __enter__(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read(self, nrows)
#    1251             nrows = validate_integer("nrows", nrows)
#    1252             try:
# -> 1253                 index, columns, col_dict = self._engine.read(nrows)
#    1254             except Exception:
#    1255                 self.close()
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in read(self, nrows)
#     223         try:
#     224             if self.low_memory:
# --> 225                 chunks = self._reader.read_low_memory(nrows)
#     226                 # destructive to chunks
#     227                 data = _concatenate_chunks(chunks)
#
# ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# StopIteration:

# %%
df_location.to_sql(name='location_data', con=engine, if_exists='replace')
# Out:
# 265

# %% [markdown]
# ### Question 3. Count records
#
# How many taxi trips were totally made on January 15?
#
# Tip: started and finished on 2019-01-15.
#
# Remember that lpep_pickup_datetime and lpep_dropoff_datetime columns are in the format timestamp (date and hour+min+sec) and not in date.

# %%
query = """
SELECT COUNT(*) FROM (SELECT  * FROM green_taxi_data
WHERE  lpep_pickup_datetime::DATE = '2019-01-15' AND lpep_pickup_datetime::DATE  = lpep_dropoff_datetime::DATE)
AS countDATA

"""

pd.read_sql(query, con=engine)
# Out:
#    count
# 0  20530

# %% [markdown]
# ### Question 4. Largest trip for each day
#
# Which was the day with the largest trip distance Use the pick up time for your calculations.

# %%
query = """

SELECT lpep_pickup_datetime::DATE  , "trip_distance" FROM green_taxi_data
ORDER BY "trip_distance"  DESC LIMIT 1

"""
pd.read_sql(query, con=engine)
# Out:
#   lpep_pickup_datetime  trip_distance
# 0           2019-01-15         117.99

# %% [markdown]
# ### Question 5. The number of passengers
#
# In 2019-01-01 how many trips had 2 and 3 passengers?

# %%
query = """
SELECT  COUNT(*) FROM green_taxi_data
WHERE passenger_count = 3 AND lpep_pickup_datetime::DATE = '2019-01-01'
"""

pd.read_sql(query, con=engine)
# Out:
#    count
# 0    254

# %%
query = """
SELECT  COUNT(*) FROM green_taxi_data
WHERE passenger_count = 2 AND lpep_pickup_datetime::DATE = '2019-01-01'
"""

pd.read_sql(query, con=engine)
# Out:
#    count
# 0   1282

# %% [markdown]
# ### Question 6. Largest tip
#
# For the passengers picked up in the Astoria Zone which was the drop off zone that had the largest tip? We want the name of the zone, not the id.

# %%
query = """
SELECT "LocationID", "DOLocationID" ,"PULocationID", "Zone", "tip_amount" FROM green_taxi_data
INNER JOIN location_data ON green_taxi_data."PULocationID" = location_data."LocationID"
WHERE "Zone" = 'Astoria' ORDER BY tip_amount DESC


"""

pd.read_sql(query, con=engine)
# Out:
#        LocationID  DOLocationID  PULocationID     Zone  tip_amount
# 0               7           146             7  Astoria       88.00
# 1               7            43             7  Astoria       30.00
# 2               7           265             7  Astoria       25.00
# 3               7           130             7  Astoria       25.00
# 4               7           265             7  Astoria       19.16
# ...           ...           ...           ...      ...         ...
# 26041           7           193             7  Astoria        0.00
# 26042           7            70             7  Astoria        0.00
# 26043           7             7             7  Astoria        0.00
# 26044           7           163             7  Astoria        0.00
# 26045           7           193             7  Astoria       -0.66
#
# [26046 rows x 5 columns]

# %%
query = """
SELECT * FROM location_data
WHERE "LocationID" = 146
"""

pd.read_sql(query, con=engine)
# Out:
#    index  LocationID Borough                           Zone service_zone
# 0    145         146  Queens  Long Island City/Queens Plaza    Boro Zone

# %%
query = """
SELECT lpep_pickup_datetime::DATE  , "trip_distance" FROM green_taxi_data
ORDER BY "trip_distance"  DESC LIMIT 1
"""

pd.read_sql(query, con=engine)
# Out:
#   lpep_pickup_datetime  trip_distance
# 0           2019-01-15         117.99
